# %% [markdown]
# # Model Ressource Management techniques
#
# * **Dimensionality and model performance**
#
#
# +high-dimesions is a real problem:
#
# More dimensions ==> More features
#
# Risk of overfitting
#
# Distances grow more and more alike
#
# ![image.png](data:image/png;base64,...)
#
#
# +Increase sparsity
#
# +The Hughes effect:

# %% [markdown]
# +More features aren't better if they don't add predictive information.
#
# +Adding features requires adding training data

# %% [markdown]
# **Manual techniques for Dimensionality Reduction**
#
#
# *Feature selection(remove duplicated,..)
#
# *Feature engineering
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ** Algorithmic Dimensionality Reduction **
#
# K-dimensional subspace for projection
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Other techniques for dimensionality Reduction
#
# depend on the problem:
#
#
#  ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Quantization and pruning
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#   **Quantization** : transforming a model into an equivalent representation that uses parameters and computations at a lower precision.
#
#   ==> improves model's exec performance and efficiency, but can result at a lower model accuracy
#
#
#   ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Post training quantization :  is a conversion technique that can reduce model size while also improving CPU and hardware accelerator latency with little degradation in model accuracy. You can quantize an already trained TensorFlow model when you convert it to TensorFlow Lite format using the TensorFlow Lite converter.
#
#
# * Quantization Aware Training :

# %% [markdown]
# # Pruning
#
# Aims to reduce params by removing and opeartions by removing network connections.
