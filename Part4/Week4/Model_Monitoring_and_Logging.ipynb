# %% [markdown]
# # Model monitoring and logging
#
# 2 types of monitoring:
#
# * ML monitoring (functionnal)
#
# -predictive performance
#
# -changes in serving data
#
# -metrics and characteristics of features
#
#
# * System monitoring ( Non functional)
#
# -system performance
#
# -system status
#
# -system reliability
#
#
# **Observability**
#
# by knowing only the input and output how weel can we infer the internal status of the system.
#
#
# **what can we monitor?**
#
# - input's and output's distributions

# %% [markdown]
# #  Privacy
#
# Human centered design == Actual user's experience is important
# ![image.png](data:image/png;base64,...)

# %%
 types
