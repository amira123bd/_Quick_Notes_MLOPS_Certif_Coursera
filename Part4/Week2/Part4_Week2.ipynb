# %% [markdown]
# # Model serving: Patterns and infrastructure

# %% [markdown]
# # Ml infrastructure:
#
# * On prem
#
# * On cloud
#
#
# High level architecture of the the model servers?
#
#
# 1.Model File= Where the model is saved
#
# 2.Model server = recieves the data, transformed it the required shape, passes it to the model file and gets the inference back.
#
#
# example of model servers:
#
# - Tensorflow serving
#
# - NVIDIA Triton
#
# - Torch serve
#
# - KFServing
#
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)
