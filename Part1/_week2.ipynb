# %% [markdown]
# # Modeling
#
#  It is a highly iterative provess
#  [Model+Data+Hyperparams==>training===> Error analysis(et re)]
#
#
#  Challenges in model dev:
#
#  * Doing well on training set
#
#  * Doing well on dev/test set
#
#  * Doing well on business metrics/project goals
#
#
# WHY low avergae error isn't good enough?
#
# -Performance on key slices of the dataset: problem of bias or discrimination like by gender
#
# -Rare classes: skewed data distribution
#
#
# *  best practices:
# Establish a baseline level of performance
#
#
# - HLP
# ![image.png](data:image/png;base64,...)
#
# - Literature search
#
# -quick and dirty implementation
#
# -perfomance of older system (if possible)
#
#
# ==> the baseline helps with giving a sense of irreducible error/Bayes error.

# %% [markdown]
# -Data Centric-approach: Holding the architecture of the model fixed and work on improving the data to do well on the problem.
#
# -model-centric approach

# %% [markdown]
# # ERROR ANALYSIS & PERFORMNACE AUDITING
#
# *landingLens:LandingLens is a computer vision cloud platform that enables users to build, iterate and deploy AI-powered solutions quickly and easily.*
#
# - by brainstorming different tags we segment our data into different categories.
#
# - Prioritize what example to work on:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ----Skewed Dataset
#
# * the given exmaple is about a skewed datset where is negative class represents the majority: we will get a recall of 0
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * In one model we can have a good precision and a good recall ==> F1-score

# %% [markdown]
# # Performance auditing
#
# before push our model into production
# we have to check for accuracy, fairness/bias and other problems.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Data augmenation : can adding data hurt?
#
# RARELY
#
# for unstructured data problems:
#
# - The model is large
#
# - The mapping x===>y is clear(like human can predict it easily)

# %% [markdown]
# Data Augmentation for sturctured data:
#
# * It is better to add new features means adding new useful infos.

# %% [markdown]
# #Experiment Tracking

# %% [markdown]
# What to track?
#
# * Algorithm/Code versioning
#
# * Dataset used
#
# * Hyperparams
#
# * Results
#
#
# Tracking tools?
#
# * Text file(for small experiments)
#
# * Spreasheets
#
# * Systems

# %% [markdown]
# #Good Data
#
#  ![image.png](data:image/png;base64,...)
